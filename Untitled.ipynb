# %%
# !cat ./OCR/Saved_texts/file_5.txt
# Out:
# ﻿                                                                               Согласие
#                                                                    на обработку персональных данных
#                                                                      (далее по тексту «Согласие»)
#
#                             Я,
#                                                            (фамилия, имя. отчество)
#  паспорт                                         №         _выдан__
#                                     (серия)                           (номер)                          (дата выдачи)
#
#                                                                           (кем выдан паспорт)
#  проживающий(ая) по адресу:
#
# (адрес места жительства по паспорту)
# в соответствии с Федеральным законом от 27 июля 2006 г. № 152-ФЗ «О персональных данных»
# (далее по тексту настоящего согласия «Федеральный закон «О персональных данных») своей
# ...

# %%
with open('./OCR/Saved_texts/file_5.txt') as f:
    msg = f.read()

# %%
upd_msg = list(map(lambda x: x.strip(), msg.split('\n')))

# %%
' '.join(upd_msg[0:upd_msg.index('')]).strip()
# Out:
# '\ufeff                                                                               Согласие на обработку персональных данных (далее по тексту «Согласие»)'

# %%
import time

# %%
import datetime

# %%
paragr = ['a', 'b', 'c', 'd']

# %%
print('\n'.join(list(map(lambda x: '/' + str(x[0]) + ' ' + x[1], zip(range(1, len(paragr)), paragr)))))
# Out:
# /1 a
# /2 b
# /3 c

# %%
get_date()
# Out:
# '07 Ноябрь 2017'

# %%
bool('2') * 'qwr'
# Out:
# 'qwr'

# %%
a = {
    1: '1'
}

# %%
list_dictionary_commands = ['/d_{}'.format(i) for i in range(1000)]

# %%
list_dictionary_commands
# Out:
# ['/d_0',
#  '/d_1',
#  '/d_2',
#  '/d_3',
#  '/d_4',
#  '/d_5',
#  '/d_6',
#  '/d_7',
#  '/d_8',
#  '/d_9',
#  '/d_10',
#  '/d_11',
#  '/d_12',
#  '/d_13',
#  '/d_14',
#  '/d_15',
#  '/d_16',
#  '/d_17',
#  '/d_18',
#  '/d_19',
#  '/d_20',
#  '/d_21',
#  '/d_22',
#  '/d_23',
#  '/d_24',
#  '/d_25',
#  '/d_26',
#  '/d_27',
#  '/d_28',
#  '/d_29',
#  '/d_30',
#  '/d_31',
#  '/d_32',
#  '/d_33',
#  '/d_34',
#  '/d_35',
#  '/d_36',
#  '/d_37',
#  '/d_38',
#  '/d_39',
#  '/d_40',
#  '/d_41',
#  '/d_42',
#  '/d_43',
#  '/d_44',
#  '/d_45',
#  '/d_46',
#  '/d_47',
#  '/d_48',
#  '/d_49',
#  '/d_50',
#  '/d_51',
#  '/d_52',
#  '/d_53',
#  '/d_54',
#  '/d_55',
#  '/d_56',
#  '/d_57',
#  '/d_58',
#  '/d_59',
#  '/d_60',
#  '/d_61',
#  '/d_62',
#  '/d_63',
#  '/d_64',
#  '/d_65',
#  '/d_66',
#  '/d_67',
#  '/d_68',
#  '/d_69',
#  '/d_70',
#  '/d_71',
#  '/d_72',
#  '/d_73',
#  '/d_74',
#  '/d_75',
#  '/d_76',
#  '/d_77',
#  '/d_78',
#  '/d_79',
#  '/d_80',
#  '/d_81',
#  '/d_82',
#  '/d_83',
# ...

# %%
a = [1, 2, 3]

# %%
list(zip(range(1, len(a)), a))
# Out:
# [(1, 1), (2, 2)]

# %%
первое_число = 1
второе_число = 2
сумма = первое_число + второе_число

# %%
сумма
# Out:
# 3
